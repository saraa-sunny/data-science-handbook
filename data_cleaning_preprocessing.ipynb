# %% [markdown]
# # Data Cleaning & Data Preprocessing

# %% [markdown]
# A quick reference notebook for data cleaning and data preprocessing steps with code examples.

# %% [markdown]
# ## 📒Table of Contents

# %% [markdown]
# 1. [Imports](#imports)
# 2. [Inspect Data](#Inspect-Data)
# 3. [Handle Missing Data](#Handle-Missing-Data)
# 4. [Fix Column Names](#Fix-Column-Names)
# 5. [Handle Duplicates](#Handle-Duplicates)
# 6.  [Convert Data Types](#Convert-Data-Types)
# 7.  [Handle Categorical Data](#Handle-Categorical-Data)
# 8.  [Text Cleaning](#Text-Cleaning)
# 9.  [Sort Data](#Sort-Data)
# 10. [Filter Data (Row Selection)](#Filter-Data-Row-Selection)
# 11. [Select Columns](#Select-Columns)
# 12. [Replace/Modify Values](#Replace-Modify-Values)
# 13. [Grouping & Aggregation](#Grouping-Aggregation)
# 14. [Index Operations](#Index-Operations)
# 15. [Save / Export Cleaned Data](#Save-Export-Cleaned-Data)
# 16. [Summary](#Summary)

# %% [markdown]
# <a id="imports"></a>
# ## 1️⃣ Imports

# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("data/obesity_dataset.csv")

# %% [markdown]
# <a id="Inspect-Data"></a>
# ## 2️⃣Inspect Data

# %%
# first 5 rows
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
# last 5 rows
df.tail()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 2106  yes   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#            CALC                 MTRANS        NObeyesdad
# ...

# %%
# rows and columns
df.shape
# Out:
# (2111, 17)

# %%
# column types + missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
# summary stats (numerical columns)
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
 # list of column names
df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
# data types
df.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
# View unique values
df['NObeyesdad'].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# Count categories
df['NObeyesdad'].value_counts()
# Out:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %% [markdown]
# <a id="Handle-Missing-Data"></a>
# ## 3️⃣ Handle Missing Data

# %%
# count missing values per column
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
# count non-missing
df.notnull().sum()
# Out:
# Gender                            2111
# Age                               2111
# Height                            2111
# Weight                            2111
# family_history_with_overweight    2111
# FAVC                              2111
# FCVC                              2111
# NCP                               2111
# CAEC                              2111
# SMOKE                             2111
# CH2O                              2111
# SCC                               2111
# FAF                               2111
# TUE                               2111
# CALC                              2111
# MTRANS                            2111
# NObeyesdad                        2111
# dtype: int64

# %%
# drop rows with any missing values
df.dropna()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
 # drop rows only if these columns have missing values
df.dropna(subset=['Gender', 'Age'])
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
# replace all missing values with 0
df.fillna(0)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
# column-specific fill
df['Age']=df['Age'].fillna(df['Age'].median())

# %% [markdown]
# <a id="Fix-Column-Names"></a>
# ## 4️⃣ Fix Column Names

# %%
# remove extra spaces
df.columns = df.columns.str.strip()

# %%
# to lowercase
df.columns = df.columns.str.lower()

# %%
# replace spaces with underscores
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['gender', 'age', 'height', 'weight', 'family_history_with_overweight',
#        'favc', 'fcvc', 'ncp', 'caec', 'smoke', 'ch2o', 'scc', 'faf', 'tue',
#        'calc', 'mtrans', 'nobeyesdad'],
#       dtype='object')

# %%
# rename columnn name
df.rename(columns={
    'gender': 'gender',
    'age': 'age',
    'height': 'height',
    'weight': 'weight',
    'family_history_with_overweight':'family_history',
    'favc':'high_caloric_food',
    'fcvc':'veggies_freq',
    'ncp':'main_meals_freq',
    'caec':'eat_between_meals',
    'smoke':'smoke',
    'ch2o':'water_l_per_day',
    'scc':'monitor_calories',
    'faf':'physical_activity_freq',
    'tue':'screen_time_hr',
    'calc':'alcohol_freq',
    'mtrans':'transport_mode',
    'nobeyesdad':'obesity_level'
}, inplace=True)
df.head()
# Out:
#    gender   age  height  weight family_history high_caloric_food  \
# 0  Female  21.0    1.62    64.0            yes                no
# 1  Female  21.0    1.52    56.0            yes                no
# 2    Male  23.0    1.80    77.0            yes                no
# 3    Male  27.0    1.80    87.0             no                no
# 4    Male  22.0    1.78    89.8             no                no
#
#    veggies_freq  main_meals_freq eat_between_meals smoke  water_l_per_day  \
# 0           2.0              3.0         Sometimes    no              2.0
# 1           3.0              3.0         Sometimes   yes              3.0
# 2           2.0              3.0         Sometimes    no              2.0
# 3           3.0              3.0         Sometimes    no              2.0
# 4           2.0              1.0         Sometimes    no              2.0
#
#   monitor_calories  physical_activity_freq  screen_time_hr alcohol_freq  \
# ...

# %%
# display the first 5 rows - to check for applied changes when needed
df.head()
# Out:
#    gender   age  height  weight family_history high_caloric_food  \
# 0  Female  21.0    1.62    64.0            yes                no
# 1  Female  21.0    1.52    56.0            yes                no
# 2    Male  23.0    1.80    77.0            yes                no
# 3    Male  27.0    1.80    87.0             no                no
# 4    Male  22.0    1.78    89.8             no                no
#
#    veggies_freq  main_meals_freq eat_between_meals smoke  water_l_per_day  \
# 0           2.0              3.0         Sometimes    no              2.0
# 1           3.0              3.0         Sometimes   yes              3.0
# 2           2.0              3.0         Sometimes    no              2.0
# 3           3.0              3.0         Sometimes    no              2.0
# 4           2.0              1.0         Sometimes    no              2.0
#
#   monitor_calories  physical_activity_freq  screen_time_hr alcohol_freq  \
# ...

# %% [markdown]
# <a id="Handle-Duplicates"></a>
# ## 5️⃣ Handle Duplicates

# %%
# count duplicates
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
# Show duplicates
df[df.duplicated()]
# Out:
#      gender   age  height  weight family_history high_caloric_food  \
# 98   Female  21.0    1.52    42.0             no                no
# 106  Female  25.0    1.57    55.0             no               yes
# 174    Male  21.0    1.62    70.0             no               yes
# 179    Male  21.0    1.62    70.0             no               yes
# 184    Male  21.0    1.62    70.0             no               yes
# 209  Female  22.0    1.69    65.0            yes               yes
# 309  Female  16.0    1.66    58.0             no                no
# 460  Female  18.0    1.62    55.0            yes               yes
# 467    Male  22.0    1.74    75.0            yes               yes
# 496    Male  18.0    1.72    53.0            yes               yes
# 527  Female  21.0    1.52    42.0             no               yes
# 659  Female  21.0    1.52    42.0             no               yes
# 663  Female  21.0    1.52    42.0             no               yes
# ...

# %%
# remove the duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# <a id="Convert-Data-Types"></a>
# ## 6️⃣ Convert Data Types

# %%
df['age'] = df['age'].astype(int)

# %%
df['height']=df['height'].astype(float)

# %% [markdown]
# <a id="Handle-Categorical-Data"></a>
# ## 7️⃣ Handle Categorical Data

# %%
# to find categorical columns 
df.select_dtypes(include='object')
# Out:
#       gender family_history high_caloric_food eat_between_meals smoke  \
# 0     Female            yes                no         Sometimes    no
# 1     Female            yes                no         Sometimes   yes
# 2       Male            yes                no         Sometimes    no
# 3       Male             no                no         Sometimes    no
# 4       Male             no                no         Sometimes    no
# ...      ...            ...               ...               ...   ...
# 2106  Female            yes               yes         Sometimes    no
# 2107  Female            yes               yes         Sometimes    no
# 2108  Female            yes               yes         Sometimes    no
# 2109  Female            yes               yes         Sometimes    no
# 2110  Female            yes               yes         Sometimes    no
#
#      monitor_calories alcohol_freq         transport_mode        obesity_level
# ...

# %%
# Encode manually
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})
df.head()
# Out:
#    gender  age  height  weight family_history high_caloric_food  veggies_freq  \
# 0       1   21    1.62    64.0            yes                no           2.0
# 1       1   21    1.52    56.0            yes                no           3.0
# 2       0   23    1.80    77.0            yes                no           2.0
# 3       0   27    1.80    87.0             no                no           3.0
# 4       0   22    1.78    89.8             no                no           2.0
#
#    main_meals_freq eat_between_meals smoke  water_l_per_day monitor_calories  \
# 0              3.0         Sometimes    no              2.0               no
# 1              3.0         Sometimes   yes              3.0              yes
# 2              3.0         Sometimes    no              2.0               no
# 3              3.0         Sometimes    no              2.0               no
# 4              1.0         Sometimes    no              2.0               no
#
# ...

# %% [markdown]
# <a id="Text-Cleaning"></a>
# ## 8️⃣ Text Cleaning

# %%
df['transport_mode'] = df['transport_mode'].str.lower().str.strip()
df.head()
# Out:
#    gender  age  height  weight family_history high_caloric_food  veggies_freq  \
# 0       1   21    1.62    64.0            yes                no           2.0
# 1       1   21    1.52    56.0            yes                no           3.0
# 2       0   23    1.80    77.0            yes                no           2.0
# 3       0   27    1.80    87.0             no                no           3.0
# 4       0   22    1.78    89.8             no                no           2.0
#
#    main_meals_freq eat_between_meals smoke  water_l_per_day monitor_calories  \
# 0              3.0         Sometimes    no              2.0               no
# 1              3.0         Sometimes   yes              3.0              yes
# 2              3.0         Sometimes    no              2.0               no
# 3              3.0         Sometimes    no              2.0               no
# 4              1.0         Sometimes    no              2.0               no
#
# ...

# %%
df['obesity_level'] = df['obesity_level'].str.replace('[^a-zA-Z ]', '', regex=True)
df.head()
# Out:
#    gender  age  height  weight family_history high_caloric_food  veggies_freq  \
# 0       1   21    1.62    64.0            yes                no           2.0
# 1       1   21    1.52    56.0            yes                no           3.0
# 2       0   23    1.80    77.0            yes                no           2.0
# 3       0   27    1.80    87.0             no                no           3.0
# 4       0   22    1.78    89.8             no                no           2.0
#
#    main_meals_freq eat_between_meals smoke  water_l_per_day monitor_calories  \
# 0              3.0         Sometimes    no              2.0               no
# 1              3.0         Sometimes   yes              3.0              yes
# 2              3.0         Sometimes    no              2.0               no
# 3              3.0         Sometimes    no              2.0               no
# 4              1.0         Sometimes    no              2.0               no
#
# ...

# %% [markdown]
# <a id="Sort-Data"></a>
# ## 9️⃣ Sort Data

# %%
# Sort by one column
df.sort_values('weight', ascending=False,inplace=True)
df.head()
# Out:
#       gender  age    height      weight family_history high_caloric_food  \
# 344        0   18  1.870000  173.000000            yes               yes
# 502        1   21  1.843419  165.057269            yes               yes
# 1898       1   19  1.793824  160.935351            yes               yes
# 1910       1   21  1.803677  160.639405            yes               yes
# 1838       1   20  1.807340  155.872093            yes               yes
#
#       veggies_freq  main_meals_freq eat_between_meals smoke  water_l_per_day  \
# 344            3.0              3.0        Frequently    no         2.000000
# 502            3.0              3.0         Sometimes    no         2.406541
# 1898           3.0              3.0         Sometimes    no         2.069257
# 1910           3.0              3.0         Sometimes    no         2.404049
# 1838           3.0              3.0         Sometimes    no         2.417122
#
# ...

# %%
# Sort by multiple columns
df.sort_values(['age', 'height'], ascending=[True, False])
# Out:
#       gender  age    height     weight family_history high_caloric_food  \
# 415        0   14  1.710000  72.000000            yes               yes
# 116        1   15  1.650000  86.000000            yes               yes
# 302        0   16  1.840000  45.000000            yes               yes
# 627        1   16  1.830068  43.534531             no               yes
# 290        0   16  1.820000  71.000000            yes               yes
# ...      ...  ...       ...        ...            ...               ...
# 1158       0   55  1.673394  80.400306            yes               yes
# 1088       0   55  1.657221  80.993213            yes               yes
# 161        0   55  1.650000  80.000000             no               yes
# 252        0   56  1.790000  90.000000            yes                no
# 133        1   61  1.650000  66.000000             no               yes
#
#       veggies_freq  main_meals_freq eat_between_meals smoke  water_l_per_day  \
# ...

# %%
# Sort by index
df.sort_index(inplace=True)
df.head()
# Out:
#    gender  age  height  weight family_history high_caloric_food  veggies_freq  \
# 0       1   21    1.62    64.0            yes                no           2.0
# 1       1   21    1.52    56.0            yes                no           3.0
# 2       0   23    1.80    77.0            yes                no           2.0
# 3       0   27    1.80    87.0             no                no           3.0
# 4       0   22    1.78    89.8             no                no           2.0
#
#    main_meals_freq eat_between_meals smoke  water_l_per_day monitor_calories  \
# 0              3.0         Sometimes    no              2.0               no
# 1              3.0         Sometimes   yes              3.0              yes
# 2              3.0         Sometimes    no              2.0               no
# 3              3.0         Sometimes    no              2.0               no
# 4              1.0         Sometimes    no              2.0               no
#
# ...

# %% [markdown]
# <a id="Filter-Data-Row-Selection"></a>
# ## 🔟 Filter Data (Row Selection)

# %%
# Single condition
df[df['age'] > 50]
# Out:
#       gender  age    height     weight family_history high_caloric_food  \
# 21         1   52  1.690000  87.000000            yes               yes
# 92         0   55  1.780000  84.000000            yes                no
# 133        1   61  1.650000  66.000000             no               yes
# 161        0   55  1.650000  80.000000             no               yes
# 232        1   51  1.590000  50.000000            yes                no
# 252        0   56  1.790000  90.000000            yes                no
# 1013       0   55  1.769269  80.491339             no               yes
# 1088       0   55  1.657221  80.993213            yes               yes
# 1158       0   55  1.673394  80.400306            yes               yes
#
#       veggies_freq  main_meals_freq eat_between_meals smoke  water_l_per_day  \
# 21             3.0              1.0         Sometimes   yes              2.0
# 92             3.0              4.0        Frequently    no              3.0
# ...

# %%
# Multiple conditions
df[(df['age'] > 50) & (df['weight'] > 65)]
# Out:
#       gender  age    height     weight family_history high_caloric_food  \
# 21         1   52  1.690000  87.000000            yes               yes
# 92         0   55  1.780000  84.000000            yes                no
# 133        1   61  1.650000  66.000000             no               yes
# 161        0   55  1.650000  80.000000             no               yes
# 252        0   56  1.790000  90.000000            yes                no
# 1013       0   55  1.769269  80.491339             no               yes
# 1088       0   55  1.657221  80.993213            yes               yes
# 1158       0   55  1.673394  80.400306            yes               yes
#
#       veggies_freq  main_meals_freq eat_between_meals smoke  water_l_per_day  \
# 21             3.0              1.0         Sometimes   yes              2.0
# 92             3.0              4.0        Frequently    no              3.0
# 133            3.0              3.0            Always    no              2.0
# ...

# %%
# Select by labels
df.loc[0:5, ['age', 'weight']]
# Out:
#    age  weight
# 0   21    64.0
# 1   21    56.0
# 2   23    77.0
# 3   27    87.0
# 4   22    89.8
# 5   29    53.0

# %%
 # Select by index
df.iloc[0:5, 0:3]
# Out:
#    gender  age  height
# 0       1   21    1.62
# 1       1   21    1.52
# 2       0   23    1.80
# 3       0   27    1.80
# 4       0   22    1.78

# %% [markdown]
# <a id="Select-Columns"></a>
# ## 1️⃣1️⃣ Select Columns

# %%
 # single column (Series)
df['height']
# Out:
# 0       1.620000
# 1       1.520000
# 2       1.800000
# 3       1.800000
# 4       1.780000
#           ...
# 2106    1.710730
# 2107    1.748584
# 2108    1.752206
# 2109    1.739450
# 2110    1.738836
# Name: height, Length: 2087, dtype: float64

# %%
df[['age', 'weight']]
# Out:
#       age      weight
# 0      21   64.000000
# 1      21   56.000000
# 2      23   77.000000
# 3      27   87.000000
# 4      22   89.800000
# ...   ...         ...
# 2106   20  131.408528
# 2107   21  133.742943
# 2108   22  133.689352
# 2109   24  133.346641
# 2110   23  133.472641
#
# [2087 rows x 2 columns]

# %%
df.select_dtypes(include='number')
# Out:
#       gender  age    height      weight  veggies_freq  main_meals_freq  \
# 0          1   21  1.620000   64.000000           2.0              3.0
# 1          1   21  1.520000   56.000000           3.0              3.0
# 2          0   23  1.800000   77.000000           2.0              3.0
# 3          0   27  1.800000   87.000000           3.0              3.0
# 4          0   22  1.780000   89.800000           2.0              1.0
# ...      ...  ...       ...         ...           ...              ...
# 2106       1   20  1.710730  131.408528           3.0              3.0
# 2107       1   21  1.748584  133.742943           3.0              3.0
# 2108       1   22  1.752206  133.689352           3.0              3.0
# 2109       1   24  1.739450  133.346641           3.0              3.0
# 2110       1   23  1.738836  133.472641           3.0              3.0
#
#       water_l_per_day  physical_activity_freq  screen_time_hr
# ...

# %%
df.select_dtypes(include='object')
# Out:
#      family_history high_caloric_food eat_between_meals smoke  \
# 0               yes                no         Sometimes    no
# 1               yes                no         Sometimes   yes
# 2               yes                no         Sometimes    no
# 3                no                no         Sometimes    no
# 4                no                no         Sometimes    no
# ...             ...               ...               ...   ...
# 2106            yes               yes         Sometimes    no
# 2107            yes               yes         Sometimes    no
# 2108            yes               yes         Sometimes    no
# 2109            yes               yes         Sometimes    no
# 2110            yes               yes         Sometimes    no
#
#      monitor_calories alcohol_freq         transport_mode      obesity_level
# 0                  no           no  public_transportation       NormalWeight
# ...

# %%
df.filter(like='age')
# Out:
#       age
# 0      21
# 1      21
# 2      23
# 3      27
# 4      22
# ...   ...
# 2106   20
# 2107   21
# 2108   22
# 2109   24
# 2110   23
#
# [2087 rows x 1 columns]

# %% [markdown]
# <a id="Replace-Modify-Values"></a>
# ## 1️⃣2️⃣ Replace/Modify Values

# %%
df.replace({'yes': 1, 'no': 0}, inplace=True)

# %%
df['smoke'] = df['smoke'].replace(0,np.nan)
df.head()
# Out:
#    gender  age  height  weight  family_history  high_caloric_food  \
# 0       1   21    1.62    64.0               1                  0
# 1       1   21    1.52    56.0               1                  0
# 2       0   23    1.80    77.0               1                  0
# 3       0   27    1.80    87.0               0                  0
# 4       0   22    1.78    89.8               0                  0
#
#    veggies_freq  main_meals_freq eat_between_meals  smoke  water_l_per_day  \
# 0           2.0              3.0         Sometimes    NaN              2.0
# 1           3.0              3.0         Sometimes    1.0              3.0
# 2           2.0              3.0         Sometimes    NaN              2.0
# 3           3.0              3.0         Sometimes    NaN              2.0
# 4           2.0              1.0         Sometimes    NaN              2.0
#
#    monitor_calories  physical_activity_freq  screen_time_hr alcohol_freq  \
# ...

# %%
df.loc[df['weight'] > 40, 'nobeyesdad'] = 'obese'
df.head()
# Out:
#    gender  age  height  weight  family_history  high_caloric_food  \
# 0       1   21    1.62    64.0               1                  0
# 1       1   21    1.52    56.0               1                  0
# 2       0   23    1.80    77.0               1                  0
# 3       0   27    1.80    87.0               0                  0
# 4       0   22    1.78    89.8               0                  0
#
#    veggies_freq  main_meals_freq eat_between_meals  smoke  water_l_per_day  \
# 0           2.0              3.0         Sometimes    NaN              2.0
# 1           3.0              3.0         Sometimes    1.0              3.0
# 2           2.0              3.0         Sometimes    NaN              2.0
# 3           3.0              3.0         Sometimes    NaN              2.0
# 4           2.0              1.0         Sometimes    NaN              2.0
#
#    monitor_calories  physical_activity_freq  screen_time_hr alcohol_freq  \
# ...

# %% [markdown]
# <a id="Grouping-Aggregation"></a>
# ## 1️⃣3️⃣ Grouping & Aggregation

# %%
df.groupby('gender')['weight'].mean()
# Out:
# gender
# 0    91.096771
# 1    82.551078
# Name: weight, dtype: float64

# %%
df.groupby('gender')[['age', 'weight']].agg(['mean', 'std', 'count'])
# Out:
#               age                     weight
#              mean       std count       mean        std count
# gender
# 0       24.340304  6.247829  1052  91.096771  21.396028  1052
# 1       23.672464  6.404481  1035  82.551078  29.693403  1035

# %% [markdown]
# <a id="Index-Operations"></a>
# ## 1️⃣4️⃣ Index Operations

# %%
df.index.name = 'id'
df.head()
# Out:
#     gender  age  height  weight  family_history  high_caloric_food  \
# id
# 0        1   21    1.62    64.0               1                  0
# 1        1   21    1.52    56.0               1                  0
# 2        0   23    1.80    77.0               1                  0
# 3        0   27    1.80    87.0               0                  0
# 4        0   22    1.78    89.8               0                  0
#
#     veggies_freq  main_meals_freq eat_between_meals  smoke  water_l_per_day  \
# id
# 0            2.0              3.0         Sometimes    NaN              2.0
# 1            3.0              3.0         Sometimes    1.0              3.0
# 2            2.0              3.0         Sometimes    NaN              2.0
# 3            3.0              3.0         Sometimes    NaN              2.0
# 4            2.0              1.0         Sometimes    NaN              2.0
#
#     monitor_calories  physical_activity_freq  screen_time_hr alcohol_freq  \
# id
# ...

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    id  gender  age  height  weight  family_history  high_caloric_food  \
# 0   0       1   21    1.62    64.0               1                  0
# 1   1       1   21    1.52    56.0               1                  0
# 2   2       0   23    1.80    77.0               1                  0
# 3   3       0   27    1.80    87.0               0                  0
# 4   4       0   22    1.78    89.8               0                  0
#
#    veggies_freq  main_meals_freq eat_between_meals  smoke  water_l_per_day  \
# 0           2.0              3.0         Sometimes    NaN              2.0
# 1           3.0              3.0         Sometimes    1.0              3.0
# 2           2.0              3.0         Sometimes    NaN              2.0
# 3           3.0              3.0         Sometimes    NaN              2.0
# 4           2.0              1.0         Sometimes    NaN              2.0
#
#    monitor_calories  physical_activity_freq  screen_time_hr alcohol_freq  \
# ...

# %%
df.set_index('id', inplace=True)
df.head()
# Out:
#     gender  age  height  weight  family_history  high_caloric_food  \
# id
# 0        1   21    1.62    64.0               1                  0
# 1        1   21    1.52    56.0               1                  0
# 2        0   23    1.80    77.0               1                  0
# 3        0   27    1.80    87.0               0                  0
# 4        0   22    1.78    89.8               0                  0
#
#     veggies_freq  main_meals_freq eat_between_meals  smoke  water_l_per_day  \
# id
# 0            2.0              3.0         Sometimes    NaN              2.0
# 1            3.0              3.0         Sometimes    1.0              3.0
# 2            2.0              3.0         Sometimes    NaN              2.0
# 3            3.0              3.0         Sometimes    NaN              2.0
# 4            2.0              1.0         Sometimes    NaN              2.0
#
#     monitor_calories  physical_activity_freq  screen_time_hr alcohol_freq  \
# id
# ...

# %% [markdown]
# <a id="Save-Export-Cleaned-Data"></a>
# ## 1️⃣5️⃣ Save / Export Cleaned Data

# %%
df.to_csv('data/cleaned_dataset.csv', index=False)

# %% [markdown]
# <a id="Summary"></a>
# ## 1️⃣6️⃣Summary

# %% [markdown]
# | No | Section | Purpose / When to Use | Key Commands / Examples |
# |---|---------|---------------------|-----------------------|
# | 1️⃣ | Imports | Load required libraries | `import pandas as pd`<br>`import numpy as np`<br>`import matplotlib.pyplot as plt`<br>`import seaborn as sns` |
# | 2️⃣ | Inspect Data | Understand dataset structure & stats | `df.head()`<br>`df.tail()`<br>`df.info()`<br>`df.describe()`<br>`df.shape` |
# | 3️⃣ | Handle Missing Data | Detect & fix missing values | `df.isna().sum()`<br>`df.dropna(inplace=True)`<br>`df['col'].fillna(df['col'].median(), inplace=True)` |
# | 4️⃣ | Fix Column Names | Clean and standardize columns | `df.rename(columns={'Old':'New'}, inplace=True)`<br>`df.columns = df.columns.str.lower()` |
# | 5️⃣ | Handle Duplicates | Remove duplicate rows | `df.drop_duplicates(inplace=True)` |
# | 6️⃣ | Convert Data Types | Change column data types | `df['col'] = df['col'].astype(int)` |
# | 7️⃣ | Handle Categorical Data | Encode categorical columns | `df['col'].map({'yes':1,'no':0})`<br>`pd.get_dummies(df, columns=['col'])` |
# | 8️⃣ | Text Cleaning | Standardize text columns | `df['text_col'] = df['text_col'].str.lower().str.strip()` |
# | 9️⃣ | Sort Data | Arrange rows in order | `df.sort_values(by='col', ascending=True, inplace=True)` |
# | 🔟 | Filter Rows | Select specific rows | `df[df['age']>25]`<br>`df.query('age > 25 and gender=="female"')` |
# | 1️⃣1️⃣ | Select Columns | Pick specific columns | `df[['col1','col2']]` |
# | 1️⃣2️⃣ | Replace / Modify Values | Change or transform data | `df['col'].replace({'old':'new'}, inplace=True)`<br>`df['col'] = df['col'].apply(lambda x: x*2)` |
# | 1️⃣3️⃣ | Grouping & Aggregation | Summarize data by groups | `df.groupby('category')['numeric'].mean()`<br>`df.groupby(['cat1','cat2']).agg({'num':'sum'})` |
# | 1️⃣4️⃣ | Index Operations | Manage DataFrame index | `df.set_index('id', inplace=True)`<br>`df.reset_index(inplace=True)`<br>`df.index.name = 'id'` |
# | 1️⃣5️⃣ | Save / Export Data | Save cleaned dataset | `df.to_csv("cleaned_data.csv", index=False)`<br>`df.to_excel("cleaned_data.xlsx", index=False)` |
